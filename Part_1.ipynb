# %% [markdown]
# # Final Project Part 1 - Proposal
#
# For my final project, I will be using a dataset of mushrooms do classify each as either edible or poisonous.
#
# **Hypothesis, Assumptions, and Goals**
#
# I want to use this data to figure out which variables will classify a mushroom as edible or poisonous. Classification is a major component necessary for my current job, for events like fraud detection. But I am unable to use their data for these class projects since the data is published publicly.
#
# I have no prior assumptions on this data. It will be purely a test as to the kind of model I can create to get a higher level of accuracy with each model iteration. With 8,123 rows and 23 columns, I hope to find the optimal variables to classify these mushrooms.
#
# This project will aid in developing better classification skills as logistic regression is a major goal for me to get out of this class.
#
#
# **Risks and Limitations**
#
# I am limited by the amount of rows. I may look into getting a more robust data set as I'd prefer 100,000 rows to better validate the models. It will require dummy-variables.
#
# **The Dataset**
#
# As shown below, this dataset includes various characteristics of the mushroom and whether it is poisonous or not. It is entirely a categorical dataset.

# %%
import pandas as pd
mushrooms = pd.read_csv('mushrooms.csv')
mushrooms.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
mushrooms.loc[:,'class'].value_counts(normalize=True)
# Out:
# e    0.517971
# p    0.482029
# Name: class, dtype: float64
